# %% [markdown]
# ## K Nearest Neighbors (KNN)
#
# It is used to classify new data based on the assumption that it is similar to its K neares neighbors. k-Nearest Neighbors (kNN) is a simple and intuitive machine learning algorithm used for both classification and regression tasks. It classifies data points based on the majority class among their k-nearest neighbors in a feature space.

# %%
import pandas as pd

adult = pd.read_csv('adult.csv')

# %%
adult.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %% [markdown]
# ### Querying the data

# %%
adult.query("workclass == '?'")
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 4       18         ?  103497  Some-college               10
# 6       29         ?  227026       HS-grad                9
# 13      58         ?  299831       HS-grad                9
# 22      72         ?  132015       7th-8th                4
# 35      65         ?  191846       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48811   35         ?  320084     Bachelors               13
# 48812   30         ?   33811     Bachelors               13
# 48820   71         ?  287372     Doctorate               16
# 48822   41         ?  202822       HS-grad                9
# 48823   72         ?  129912       HS-grad                9
#
#            marital-status occupation   relationship                race  \
# 4           Never-married          ?      Own-child               White
# 6           Never-married          ?      Unmarried               Black
# 13     Married-civ-spouse          ?        Husband               White
# 22               Divorced          ?  Not-in-family               White
# 35     Married-civ-spouse          ?        Husband               White
# ...                   ...        ...            ...                 ...
# 48811  Married-civ-spouse          ?           Wife               White
# 48812       Never-married          ?  Not-in-family  Asian-Pac-Islander
# 48820  Married-civ-spouse          ?        Husband               White
# 48822           Separated          ?  Not-in-family               Black
# 48823  Married-civ-spouse          ?        Husband               White
#
#        gender  capital-gain  capital-loss  hours-per-week native-country  \
# 4      Female             0             0              30  United-States
# 6        Male             0             0              40  United-States
# 13       Male             0             0              35  United-States
# 22     Female             0             0               6  United-States
# 35       Male             0             0              40  United-States
# ...       ...           ...           ...             ...            ...
# 48811  Female             0             0              55  United-States
# 48812  Female             0             0              99  United-States
# 48820    Male             0             0              10  United-States
# 48822  Female             0             0              32  United-States
# 48823    Male             0             0              25  United-States
#
#       income
# 4      <=50K
# 6      <=50K
# 13     <=50K
# 22     <=50K
# 35     <=50K
# ...      ...
# 48811   >50K
# 48812  <=50K
# 48820   >50K
# 48822  <=50K
# 48823  <=50K
#
# [2799 rows x 15 columns]

# %% [markdown]
# ### Converting the Categorical columns to Numerical columns
#
# Here, I will be converting the ordinal categorical columns to numerical columns using the LabelEncoder module from the sklearn.preprocessing.

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
adult['income'] = lb.fit_transform(adult['income'])
adult['relationship'] = lb.fit_transform(adult['relationship'])
adult['marital-status'] = lb.fit_transform(adult['marital-status'])
adult['education'] = lb.fit_transform(adult['education'])
adult['workclass'] = lb.fit_transform(adult['workclass'])
adult['occupation'] = lb.fit_transform(adult['occupation'])

# %% [markdown]
# ## Converting Norminal columns to Numerical
#
# Here, I will be converting the norminal categorical columns to numerical columns using the get_dummies module from Pandas.

# %%
adult = pd.get_dummies(adult, columns = ['race', 'gender', 'native-country'])

# %%
adult.head(10)
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   25          4  226802          1                7               4
# 1   38          4   89814         11                9               2
# 2   28          2  336951          7               12               2
# 3   44          4  160323         15               10               2
# 4   18          0  103497         15               10               4
# 5   34          4  198693          0                6               4
# 6   29          0  227026         11                9               4
# 7   63          6  104626         14               15               2
# 8   24          4  369667         15               10               4
# 9   55          4  104996          5                4               2
#
#    occupation  relationship  capital-gain  capital-loss  ...  \
# 0           7             3             0             0  ...
# 1           5             0             0             0  ...
# 2          11             0             0             0  ...
# 3           7             0          7688             0  ...
# 4           0             3             0             0  ...
# 5           8             1             0             0  ...
# 6           0             4             0             0  ...
# 7          10             0          3103             0  ...
# 8           8             4             0             0  ...
# 9           3             0             0             0  ...
#
#    native-country_Portugal  native-country_Puerto-Rico  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 3                    False                       False
# 4                    False                       False
# 5                    False                       False
# 6                    False                       False
# 7                    False                       False
# 8                    False                       False
# 9                    False                       False
#
#    native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                    False                 False                  False
# 1                    False                 False                  False
# 2                    False                 False                  False
# 3                    False                 False                  False
# 4                    False                 False                  False
# 5                    False                 False                  False
# 6                    False                 False                  False
# 7                    False                 False                  False
# 8                    False                 False                  False
# 9                    False                 False                  False
#
#    native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                    False                           False
# 1                    False                           False
# 2                    False                           False
# 3                    False                           False
# 4                    False                           False
# 5                    False                           False
# 6                    False                           False
# 7                    False                           False
# 8                    False                           False
# 9                    False                           False
#
#    native-country_United-States  native-country_Vietnam  \
# 0                          True                   False
# 1                          True                   False
# 2                          True                   False
# 3                          True                   False
# 4                          True                   False
# 5                          True                   False
# 6                          True                   False
# 7                          True                   False
# 8                          True                   False
# 9                          True                   False
#
#    native-country_Yugoslavia
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 9                      False
#
# [10 rows x 61 columns]

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 61 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        48842 non-null  int64
#  1   workclass                                  48842 non-null  int32
#  2   fnlwgt                                     48842 non-null  int64
#  3   education                                  48842 non-null  int32
#  4   educational-num                            48842 non-null  int64
#  5   marital-status                             48842 non-null  int32
#  6   occupation                                 48842 non-null  int32
#  7   relationship                               48842 non-null  int32
#  8   capital-gain                               48842 non-null  int64
#  9   capital-loss                               48842 non-null  int64
#  10  hours-per-week                             48842 non-null  int64
#  11  income                                     48842 non-null  int32
#  12  race_Amer-Indian-Eskimo                    48842 non-null  bool
#  13  race_Asian-Pac-Islander                    48842 non-null  bool
#  14  race_Black                                 48842 non-null  bool
#  15  race_Other                                 48842 non-null  bool
#  16  race_White                                 48842 non-null  bool
#  17  gender_Female                              48842 non-null  bool
#  18  gender_Male                                48842 non-null  bool
#  19  native-country_?                           48842 non-null  bool
#  20  native-country_Cambodia                    48842 non-null  bool
#  21  native-country_Canada                      48842 non-null  bool
#  22  native-country_China                       48842 non-null  bool
#  23  native-country_Columbia                    48842 non-null  bool
#  24  native-country_Cuba                        48842 non-null  bool
#  25  native-country_Dominican-Republic          48842 non-null  bool
#  26  native-country_Ecuador                     48842 non-null  bool
#  27  native-country_El-Salvador                 48842 non-null  bool
#  28  native-country_England                     48842 non-null  bool
#  29  native-country_France                      48842 non-null  bool
#  30  native-country_Germany                     48842 non-null  bool
#  31  native-country_Greece                      48842 non-null  bool
#  32  native-country_Guatemala                   48842 non-null  bool
#  33  native-country_Haiti                       48842 non-null  bool
#  34  native-country_Holand-Netherlands          48842 non-null  bool
#  35  native-country_Honduras                    48842 non-null  bool
#  36  native-country_Hong                        48842 non-null  bool
#  37  native-country_Hungary                     48842 non-null  bool
#  38  native-country_India                       48842 non-null  bool
#  39  native-country_Iran                        48842 non-null  bool
#  40  native-country_Ireland                     48842 non-null  bool
#  41  native-country_Italy                       48842 non-null  bool
#  42  native-country_Jamaica                     48842 non-null  bool
#  43  native-country_Japan                       48842 non-null  bool
#  44  native-country_Laos                        48842 non-null  bool
#  45  native-country_Mexico                      48842 non-null  bool
#  46  native-country_Nicaragua                   48842 non-null  bool
#  47  native-country_Outlying-US(Guam-USVI-etc)  48842 non-null  bool
#  48  native-country_Peru                        48842 non-null  bool
#  49  native-country_Philippines                 48842 non-null  bool
#  50  native-country_Poland                      48842 non-null  bool
#  51  native-country_Portugal                    48842 non-null  bool
#  52  native-country_Puerto-Rico                 48842 non-null  bool
#  53  native-country_Scotland                    48842 non-null  bool
#  54  native-country_South                       48842 non-null  bool
#  55  native-country_Taiwan                      48842 non-null  bool
#  56  native-country_Thailand                    48842 non-null  bool
#  57  native-country_Trinadad&Tobago             48842 non-null  bool
#  58  native-country_United-States               48842 non-null  bool
#  59  native-country_Vietnam                     48842 non-null  bool
#  60  native-country_Yugoslavia                  48842 non-null  bool
# dtypes: bool(49), int32(6), int64(6)
# memory usage: 5.6 MB

# %%
y = adult['income']
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: income, Length: 48842, dtype: int32

# %%
x = adult.drop('income', axis = 1)
x
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0       25          4  226802          1                7               4
# 1       38          4   89814         11                9               2
# 2       28          2  336951          7               12               2
# 3       44          4  160323         15               10               2
# 4       18          0  103497         15               10               4
# ...    ...        ...     ...        ...              ...             ...
# 48837   27          4  257302          7               12               2
# 48838   40          4  154374         11                9               2
# 48839   58          4  151910         11                9               6
# 48840   22          4  201490         11                9               4
# 48841   52          5  287927         11                9               2
#
#        occupation  relationship  capital-gain  capital-loss  ...  \
# 0               7             3             0             0  ...
# 1               5             0             0             0  ...
# 2              11             0             0             0  ...
# 3               7             0          7688             0  ...
# 4               0             3             0             0  ...
# ...           ...           ...           ...           ...  ...
# 48837          13             5             0             0  ...
# 48838           7             0             0             0  ...
# 48839           1             4             0             0  ...
# 48840           1             3             0             0  ...
# 48841           4             5         15024             0  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ...                        ...                         ...
# 48837                    False                       False
# 48838                    False                       False
# 48839                    False                       False
# 48840                    False                       False
# 48841                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 2                        False                 False                  False
# 3                        False                 False                  False
# 4                        False                 False                  False
# ...                        ...                   ...                    ...
# 48837                    False                 False                  False
# 48838                    False                 False                  False
# 48839                    False                 False                  False
# 48840                    False                 False                  False
# 48841                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ...                        ...                             ...
# 48837                    False                           False
# 48838                    False                           False
# 48839                    False                           False
# 48840                    False                           False
# 48841                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 2                              True                   False
# 3                              True                   False
# 4                              True                   False
# ...                             ...                     ...
# 48837                          True                   False
# 48838                          True                   False
# 48839                          True                   False
# 48840                          True                   False
# 48841                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 48837                      False
# 48838                      False
# 48839                      False
# 48840                      False
# 48841                      False
#
# [48842 rows x 60 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x_test)

# %%
knn.score(x_test, y_test)
# Out:
# 0.7630258982495649

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7630258982495649

# %%
adult['income'].sample(200)
# Out:
# 31501    0
# 26149    1
# 26146    1
# 17484    1
# 36359    0
#         ..
# 18058    0
# 27415    0
# 40900    0
# 34030    0
# 48341    0
# Name: income, Length: 200, dtype: int32

# %%
adult_0 = adult[adult['income'] == 0]
adult_0
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0       25          4  226802          1                7               4
# 1       38          4   89814         11                9               2
# 4       18          0  103497         15               10               4
# 5       34          4  198693          0                6               4
# 6       29          0  227026         11                9               4
# ...    ...        ...     ...        ...              ...             ...
# 48834   32          4  116138         12               14               4
# 48836   22          4  310152         15               10               4
# 48837   27          4  257302          7               12               2
# 48839   58          4  151910         11                9               6
# 48840   22          4  201490         11                9               4
#
#        occupation  relationship  capital-gain  capital-loss  ...  \
# 0               7             3             0             0  ...
# 1               5             0             0             0  ...
# 4               0             3             0             0  ...
# 5               8             1             0             0  ...
# 6               0             4             0             0  ...
# ...           ...           ...           ...           ...  ...
# 48834          13             1             0             0  ...
# 48836          11             1             0             0  ...
# 48837          13             5             0             0  ...
# 48839           1             4             0             0  ...
# 48840           1             3             0             0  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 0                        False                       False
# 1                        False                       False
# 4                        False                       False
# 5                        False                       False
# 6                        False                       False
# ...                        ...                         ...
# 48834                    False                       False
# 48836                    False                       False
# 48837                    False                       False
# 48839                    False                       False
# 48840                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 0                        False                 False                  False
# 1                        False                 False                  False
# 4                        False                 False                  False
# 5                        False                 False                  False
# 6                        False                 False                  False
# ...                        ...                   ...                    ...
# 48834                    False                 False                   True
# 48836                    False                 False                  False
# 48837                    False                 False                  False
# 48839                    False                 False                  False
# 48840                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 0                        False                           False
# 1                        False                           False
# 4                        False                           False
# 5                        False                           False
# 6                        False                           False
# ...                        ...                             ...
# 48834                    False                           False
# 48836                    False                           False
# 48837                    False                           False
# 48839                    False                           False
# 48840                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 0                              True                   False
# 1                              True                   False
# 4                              True                   False
# 5                              True                   False
# 6                              True                   False
# ...                             ...                     ...
# 48834                         False                   False
# 48836                          True                   False
# 48837                          True                   False
# 48839                          True                   False
# 48840                          True                   False
#
#        native-country_Yugoslavia
# 0                          False
# 1                          False
# 4                          False
# 5                          False
# 6                          False
# ...                          ...
# 48834                      False
# 48836                      False
# 48837                      False
# 48839                      False
# 48840                      False
#
# [37155 rows x 61 columns]

# %%
adult_1 = adult[adult['income'] == 1]
adult_1
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 2       28          2  336951          7               12               2
# 3       44          4  160323         15               10               2
# 7       63          6  104626         14               15               2
# 10      65          4  184454         11                9               2
# 14      48          4  279724         11                9               2
# ...    ...        ...     ...        ...              ...             ...
# 48820   71          0  287372         10               16               2
# 48826   39          2  111499          7               12               2
# 48835   53          4  321865         12               14               2
# 48838   40          4  154374         11                9               2
# 48841   52          5  287927         11                9               2
#
#        occupation  relationship  capital-gain  capital-loss  ...  \
# 2              11             0             0             0  ...
# 3               7             0          7688             0  ...
# 7              10             0          3103             0  ...
# 10              7             0          6418             0  ...
# 14              7             0          3103             0  ...
# ...           ...           ...           ...           ...  ...
# 48820           0             0             0             0  ...
# 48826           1             5             0             0  ...
# 48835           4             0             0             0  ...
# 48838           7             0             0             0  ...
# 48841           4             5         15024             0  ...
#
#        native-country_Portugal  native-country_Puerto-Rico  \
# 2                        False                       False
# 3                        False                       False
# 7                        False                       False
# 10                       False                       False
# 14                       False                       False
# ...                        ...                         ...
# 48820                    False                       False
# 48826                    False                       False
# 48835                    False                       False
# 48838                    False                       False
# 48841                    False                       False
#
#        native-country_Scotland  native-country_South  native-country_Taiwan  \
# 2                        False                 False                  False
# 3                        False                 False                  False
# 7                        False                 False                  False
# 10                       False                 False                  False
# 14                       False                 False                  False
# ...                        ...                   ...                    ...
# 48820                    False                 False                  False
# 48826                    False                 False                  False
# 48835                    False                 False                  False
# 48838                    False                 False                  False
# 48841                    False                 False                  False
#
#        native-country_Thailand  native-country_Trinadad&Tobago  \
# 2                        False                           False
# 3                        False                           False
# 7                        False                           False
# 10                       False                           False
# 14                       False                           False
# ...                        ...                             ...
# 48820                    False                           False
# 48826                    False                           False
# 48835                    False                           False
# 48838                    False                           False
# 48841                    False                           False
#
#        native-country_United-States  native-country_Vietnam  \
# 2                              True                   False
# 3                              True                   False
# 7                              True                   False
# 10                             True                   False
# 14                             True                   False
# ...                             ...                     ...
# 48820                          True                   False
# 48826                          True                   False
# 48835                          True                   False
# 48838                          True                   False
# 48841                          True                   False
#
#        native-country_Yugoslavia
# 2                          False
# 3                          False
# 7                          False
# 10                         False
# 14                         False
# ...                          ...
# 48820                      False
# 48826                      False
# 48835                      False
# 48838                      False
# 48841                      False
#
# [11687 rows x 61 columns]

# %% [markdown]
# ### Hyperparameter tuning
#
# The idea is to know the value of k within any specified range with the best accuracy.

# %%
for k in range(1, 11):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    y_pred = knn.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f'k = {k}, Accuracy: {accuracy * 100:.2f}%')
# Out:
# k = 1, Accuracy: 73.60%
# k = 2, Accuracy: 79.28%
# k = 3, Accuracy: 76.30%
# k = 4, Accuracy: 80.00%
# k = 5, Accuracy: 78.32%
# k = 6, Accuracy: 80.06%
# k = 7, Accuracy: 79.28%
# k = 8, Accuracy: 80.19%
# k = 9, Accuracy: 79.52%
# k = 10, Accuracy: 80.41%

# %% [markdown]
# ### Plot confusion matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[7292,  187],
#        [1727,  563]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.xlabel('Predicted')
plt.ylabel('Actual')
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report

cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88      7479
#            1       0.75      0.25      0.37      2290
#
#     accuracy                           0.80      9769
#    macro avg       0.78      0.61      0.63      9769
# weighted avg       0.79      0.80      0.76      9769
