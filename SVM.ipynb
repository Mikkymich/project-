# %% [markdown]
# ### Support Vector Machines (SVM)
#
# Here we will be going throught the regression aspect of the SVM. SVM is a type of supervised machine learning model used for classification and regression tasks. The primary goal of SVM is to find a hyperplane that best separates the data into different classes.

# %%
import pandas as pd

earthquake = pd.read_csv('Earthquake_data_dataset.csv')
earthquake.head()
# Out:
#                                           title  magnitude         date_time  \
# 0  M 7.0 - 18 km SW of Malango, Solomon Islands        7.0  22-11-2022 02:03
# 1      M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9  18-11-2022 13:37
# 2                                      M 7.0 -         7.0  12-11-2022 07:09
# 3           M 7.3 - 205 km ESE of Neiafu, Tonga        7.3  11-11-2022 10:48
# 4                                      M 6.6 -         6.6  09-11-2022 10:14
#
#    cdi  mmi  tsunami  sig net  nst   dmin   gap magType    depth  latitude  \
# 0    8    7        1  768  us  117  0.509  17.0     mww   14.000   -9.7963
# 1    4    4        0  735  us   99  2.229  34.0     mww   25.000   -4.9559
# 2    3    3        1  755  us  147  3.125  18.0     mww  579.000  -20.0508
# 3    5    5        1  833  us  149  1.865  21.0     mww   37.000  -19.2918
# 4    0    2        1  670  us  131  4.998  27.0     mww  624.464  -25.5948
#
#    longitude          country
# 0    159.596  Solomon Islands
# 1    100.738              NaN
# 2   -178.346             Fiji
# 3   -172.129              NaN
# 4    178.278              NaN

# %%
earthquake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      782 non-null    object
#  1   magnitude  782 non-null    float64
#  2   date_time  782 non-null    object
#  3   cdi        782 non-null    int64
#  4   mmi        782 non-null    int64
#  5   tsunami    782 non-null    int64
#  6   sig        782 non-null    int64
#  7   net        782 non-null    object
#  8   nst        782 non-null    int64
#  9   dmin       782 non-null    float64
#  10  gap        782 non-null    float64
#  11  magType    782 non-null    object
#  12  depth      782 non-null    float64
#  13  latitude   782 non-null    float64
#  14  longitude  782 non-null    float64
#  15  country    484 non-null    object
# dtypes: float64(6), int64(5), object(5)
# memory usage: 97.9+ KB

# %%
earthquake.describe()
# Out:
#         magnitude         cdi         mmi     tsunami          sig  \
# count  782.000000  782.000000  782.000000  782.000000   782.000000
# mean     6.941125    4.333760    5.964194    0.388747   870.108696
# std      0.445514    3.169939    1.462724    0.487778   322.465367
# min      6.500000    0.000000    1.000000    0.000000   650.000000
# 25%      6.600000    0.000000    5.000000    0.000000   691.000000
# 50%      6.800000    5.000000    6.000000    0.000000   754.000000
# 75%      7.100000    7.000000    7.000000    1.000000   909.750000
# max      9.100000    9.000000    9.000000    1.000000  2910.000000
#
#               nst        dmin         gap       depth    latitude   longitude
# count  782.000000  782.000000  782.000000  782.000000  782.000000  782.000000
# mean   230.250639    1.325757   25.038990   75.883199    3.538100   52.609199
# std    250.188177    2.218805   24.225067  137.277078   27.303429  117.898886
# min      0.000000    0.000000    0.000000    2.700000  -61.848400 -179.968000
# 25%      0.000000    0.000000   14.625000   14.000000  -14.595600  -71.668050
# 50%    140.000000    0.000000   20.000000   26.295000   -2.572500  109.426000
# 75%    445.000000    1.863000   30.000000   49.750000   24.654500  148.941000
# max    934.000000   17.654000  239.000000  670.810000   71.631200  179.662000

# %%
earthquake.isnull().sum()
# Out:
# title          0
# magnitude      0
# date_time      0
# cdi            0
# mmi            0
# tsunami        0
# sig            0
# net            0
# nst            0
# dmin           0
# gap            0
# magType        0
# depth          0
# latitude       0
# longitude      0
# country      298
# dtype: int64

# %%
earthquake.drop(['country', 'date_time', 'net', 'title'], axis = 1, inplace = True)

# %%
earthquake.head()
# Out:
#    magnitude  cdi  mmi  tsunami  sig  nst   dmin   gap magType    depth  \
# 0        7.0    8    7        1  768  117  0.509  17.0     mww   14.000
# 1        6.9    4    4        0  735   99  2.229  34.0     mww   25.000
# 2        7.0    3    3        1  755  147  3.125  18.0     mww  579.000
# 3        7.3    5    5        1  833  149  1.865  21.0     mww   37.000
# 4        6.6    0    2        1  670  131  4.998  27.0     mww  624.464
#
#    latitude  longitude
# 0   -9.7963    159.596
# 1   -4.9559    100.738
# 2  -20.0508   -178.346
# 3  -19.2918   -172.129
# 4  -25.5948    178.278

# %%
earthquake = pd.get_dummies(earthquake, columns = ['magType'])

# %%
x = earthquake.iloc[:, 1:]
y = earthquake.iloc[:, 0]

# %%
earthquake.head()
# Out:
#    magnitude  cdi  mmi  tsunami  sig  nst   dmin   gap    depth  latitude  \
# 0        7.0    8    7        1  768  117  0.509  17.0   14.000   -9.7963
# 1        6.9    4    4        0  735   99  2.229  34.0   25.000   -4.9559
# 2        7.0    3    3        1  755  147  3.125  18.0  579.000  -20.0508
# 3        7.3    5    5        1  833  149  1.865  21.0   37.000  -19.2918
# 4        6.6    0    2        1  670  131  4.998  27.0  624.464  -25.5948
#
#    longitude  magType_Mi  magType_mb  magType_md  magType_ml  magType_ms  \
# 0    159.596       False       False       False       False       False
# 1    100.738       False       False       False       False       False
# 2   -178.346       False       False       False       False       False
# 3   -172.129       False       False       False       False       False
# 4    178.278       False       False       False       False       False
#
#    magType_mw  magType_mwb  magType_mwc  magType_mww
# 0       False        False        False         True
# 1       False        False        False         True
# 2       False        False        False         True
# 3       False        False        False         True
# 4       False        False        False         True

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.svm import SVR

model = SVR()
model.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'The mean squared error is {mse}')
print(f'The r squared value is {r2}')
# Out:
# The mean squared error is 0.06660915541169483
# The r squared value is 0.5175289239662457

# %%
predictions = pd.DataFrame({'Actual values': y_test,'predicted values':y_pred})
predictions
# Out:
#      Actual values  predicted values
# 596            6.5          6.708064
# 588            6.7          6.715540
# 208            6.5          6.601125
# 291            7.0          6.891346
# 174            6.9          6.890633
# ..             ...               ...
# 79             6.9          6.839076
# 148            6.8          6.792730
# 334            6.7          6.654785
# 204            6.8          7.163239
# 296            6.8          6.758233
#
# [157 rows x 2 columns]

# %% [markdown]
# ### Parameters Tuning
#
# In this stage, we will be adjusting the parameters in order to improve the model metrics. Note that the smaller the mean squared error, the better the machine learning model.
#
# The parameters we will be considering are: regualarization(C), gamma, and kernel

# %%
# regularization

model_C = SVR(C = 45)
model_C.fit(x_train, y_train)
# Out:
# SVR(C=45)

# %%
y_predC = model_C.predict(x_test)

# %%
mse_C = mean_squared_error(y_test, y_predC)
print(f'The mean squared error is {mse_C}')
# Out:
# The mean squared error is 0.07144830566082701

# %%
# gamma

model_g = SVR(gamma = 10)
model_g.fit(x_train, y_train)
# Out:
# SVR(gamma=10)

# %%
y_predG = model_g.predict(x_test)

# %%
mse_g = mean_squared_error(y_test, y_predG)
print(f'The mean squared error is {mse_g}')
# Out:
# The mean squared error is 0.15237464500500444

# %%
# kernel

model_kernel = SVR()
